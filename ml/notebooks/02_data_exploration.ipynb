# %% [markdown]
# # 02 - Data Exploration
#
# Exploratory data analysis for nutrient sensor readings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
DATA_PATH = '../data/processed/'

# %%
# TODO: Implement data exploration and visualization
